# %%
import numpy as np
import pandas as pd
import optuna

# %%
ls | grep sqlite3
# Out:
# cmap_GATv2Conv.sqlite3
# cmap_GCNConv.sqlite3
# cmap_transformer.sqlite3
# GATv2Conv.sqlite3
# GCNConv.sqlite3
# TransformerConv.sqlite3

# %%
study = optuna.create_study(
    storage="sqlite:///GCNConv.sqlite3",
    study_name="GCNConv",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:40,022] Using an existing study with name 'GCNConv' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 272     272  2.093818e+10  3.964944e+09 2023-12-22 05:03:05.975441
# 327     327  2.088884e+10  3.968885e+09 2023-12-22 14:26:18.008746
# 368     368  2.076128e+10  3.969615e+09 2023-12-22 21:05:37.126235
# 274     274  2.083508e+10  3.971461e+09 2023-12-22 05:29:07.782205
# 154     154  2.085072e+10  3.972088e+09 2023-12-21 10:58:51.362209
#
#              datetime_complete               duration  params_batch_size  \
# 272 2023-12-22 05:16:24.760518 0 days 00:13:18.785077                150
# 327 2023-12-22 14:39:44.272078 0 days 00:13:26.263332                150
# 368 2023-12-22 21:19:04.650289 0 days 00:13:27.524054                150
# 274 2023-12-22 05:42:28.169256 0 days 00:13:20.387051                150
# 154 2023-12-21 11:05:39.249770 0 days 00:06:47.887561                150
#
# ...

# %%
study = optuna.create_study(
    storage="sqlite:///GATv2Conv.sqlite3",
    study_name="GATv2Conv",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:40,268] Using an existing study with name 'GATv2Conv' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 147     147  2.091275e+10  3.954852e+09 2023-12-21 23:21:46.044285
# 329     329  2.063597e+10  3.960028e+09 2023-12-23 23:58:22.315234
# 32       32  2.078266e+10  3.963355e+09 2023-12-20 21:05:45.037250
# 291     291  1.971759e+10  3.965858e+09 2023-12-23 12:51:14.493313
# 68       68  2.147563e+10  3.971050e+09 2023-12-21 03:47:02.545003
#
#              datetime_complete               duration  params_batch_size  \
# 147 2023-12-21 23:41:19.021013 0 days 00:19:32.976728                150
# 329 2023-12-24 00:21:12.670098 0 days 00:22:50.354864                150
# 32  2023-12-20 21:17:03.449385 0 days 00:11:18.412135                150
# 291 2023-12-23 13:09:27.777904 0 days 00:18:13.284591                150
# 68  2023-12-21 04:09:25.432018 0 days 00:22:22.887015                150
#
# ...

# %%
study = optuna.create_study(
    storage="sqlite:///TransformerConv.sqlite3",
    study_name="TransformerConv",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:40,548] Using an existing study with name 'TransformerConv' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 341     341  2.038298e+10  3.828995e+09 2023-12-24 10:00:45.254262
# 288     288  2.071166e+10  3.850207e+09 2023-12-23 16:34:16.617685
# 68       68  2.035273e+10  3.894555e+09 2023-12-21 02:48:08.489167
# 157     157  2.029026e+10  3.908564e+09 2023-12-22 00:59:32.936263
# 297     297  1.996556e+10  3.935688e+09 2023-12-23 19:31:14.607043
#
#              datetime_complete               duration  params_batch_size  \
# 341 2023-12-24 10:21:20.153646 0 days 00:20:34.899384                 50
# 288 2023-12-23 16:56:28.467113 0 days 00:22:11.849428                150
# 68  2023-12-21 03:11:10.004407 0 days 00:23:01.515240                 50
# 157 2023-12-22 01:23:08.540480 0 days 00:23:35.604217                 50
# 297 2023-12-23 19:54:32.322610 0 days 00:23:17.715567                 50
#
# ...

# %%
study = optuna.create_study(
    storage="sqlite:///cmap_GATv2Conv.sqlite3",
    study_name="GATv2Conv",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:40,816] Using an existing study with name 'GATv2Conv' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 143     143  1.513416e+10  1.333533e+09 2023-12-24 11:32:44.114345
# 106     106  1.841163e+10  1.341265e+09 2023-12-23 07:25:34.967897
# 133     133  1.161730e+10  1.352082e+09 2023-12-24 03:17:30.474316
# 122     122  1.191996e+10  1.370306e+09 2023-12-23 18:42:42.271098
# 7         7  1.334633e+10  1.388789e+09 2023-12-20 21:08:14.683051
#
#              datetime_complete               duration  params_batch_size  \
# 143 2023-12-24 12:04:10.178732 0 days 00:31:26.064387                 10
# 106 2023-12-23 08:29:32.710771 0 days 01:03:57.742874                 25
# 133 2023-12-24 04:05:15.378624 0 days 00:47:44.904308                 50
# 122 2023-12-23 19:51:07.127236 0 days 01:08:24.856138                 10
# 7   2023-12-20 21:33:37.152367 0 days 00:25:22.469316                 50
#
# ...

# %%
study = optuna.create_study(
    storage="sqlite:///cmap_GCNConv.sqlite3",
    study_name="cmap_GCNConv",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:40,974] Using an existing study with name 'cmap_GCNConv' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 8         8  1.177520e+10  1.243170e+09 2023-12-20 21:20:26.697783
# 49       49  1.168699e+10  1.247218e+09 2023-12-21 14:12:43.102398
# 101     101  1.162957e+10  1.255023e+09 2023-12-22 22:55:07.334843
# 41       41  1.163426e+10  1.257480e+09 2023-12-21 10:35:05.352755
# 59       59  1.174549e+10  1.260017e+09 2023-12-21 18:29:46.408591
#
#              datetime_complete               duration  params_batch_size  \
# 8   2023-12-20 22:12:26.471004 0 days 00:51:59.773221                 25
# 49  2023-12-21 15:02:42.257504 0 days 00:49:59.155106                 25
# 101 2023-12-23 00:36:17.502746 0 days 01:41:10.167903                 25
# 41  2023-12-21 11:30:25.977986 0 days 00:55:20.625231                 25
# 59  2023-12-21 19:18:43.763791 0 days 00:48:57.355200                 25
#
# ...

# %%
study = optuna.create_study(
    storage="sqlite:///cmap_transformer.sqlite3",
    study_name="transformer",
    load_if_exists=True,
)
study.trials_dataframe().dropna().sort_values('values_1').head()
# Out:
# [I 2024-01-03 17:06:41,204] Using an existing study with name 'transformer' instead of creating a new one.
#      number      values_0      values_1             datetime_start  \
# 57       57  1.180780e+10  1.243748e+09 2023-12-22 06:05:40.952124
# 55       55  1.175438e+10  1.250320e+09 2023-12-22 05:04:47.059594
# 79       79  1.182653e+10  1.271203e+09 2023-12-22 19:16:37.875821
# 110     110  1.159352e+10  1.274766e+09 2023-12-23 19:01:28.258644
# 87       87  1.207696e+10  1.290640e+09 2023-12-23 00:38:49.723697
#
#              datetime_complete               duration  params_batch_size  \
# 57  2023-12-22 06:57:19.786291 0 days 00:51:38.834167                 50
# 55  2023-12-22 05:58:24.230912 0 days 00:53:37.171318                 50
# 79  2023-12-22 19:43:12.134049 0 days 00:26:34.258228                 50
# 110 2023-12-23 19:57:10.901238 0 days 00:55:42.642594                 50
# 87  2023-12-23 01:05:08.136796 0 days 00:26:18.413099                 50
#
# ...
